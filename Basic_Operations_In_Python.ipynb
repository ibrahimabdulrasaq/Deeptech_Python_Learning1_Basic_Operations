# %%
print ("Welcome to python")
# Out:
# Welcome to python

# %%
coffee_price = 200
daily_expenses = coffee_price * 7

print("Weekly coffee expences:", daily_expenses)
# Out:
# Weekly coffee expences: 1400

# %%
mark_score=70
science_score=80
total_score=mark_score+science_score

print("Total Marks:", total_score)
# Out:
# Total Marks: 150

# %%
name = "ibrahim"
print('Hello', name , 'welcome to python')
# Out:
# Hello ibrahim welcome to python

# %%
quote = 'practice makes perfect'

print(quote.upper())
print(quote.lower())
print(quote.replace('perfect', 'progress'))
# Out:
# PRACTICE MAKES PERFECT
# practice makes perfect
# practice makes progress

# %%
first_name = 'Ibrahim'
last_name = 'Abdulrasq'

print('Full Name:', first_name + ' ' + last_name)
# Out:
# Full Name: Ibrahim Abdulrasq

# %%
first_name = 'Ibrahim'
last_name = 'Abdulrasq'

print('Full Name:', first_name + last_name)

first_name = 'Ibrahim'
last_name = 'Abdulrasq'

print('Full Name:', first_name + ' ' + last_name)
# Out:
# Full Name: IbrahimAbdulrasq
# Full Name: Ibrahim Abdulrasq

# %%
shopping_list = ['bread', 'eggs', 'tea', 'onion']
shopping_list.append('butter')

print('Updated shopping list:', shopping_list)
# Out:
# Updated shopping list: ['bread', 'eggs', 'tea', 'onion', 'butter']

# %%
# Exam Score

scores = [85,90, 78, 52,60]
print('Highest score:', max(scores))
print('Average Score:', sum(scores)/len(scores))
# Out:
# Hihest score: 90
# Average Score: 73.0

# %%
# Multiplication table

for i in range (1,11):
    print(f'5 x {i}=', 5 * i)
# Out:
# 5 x 1= 5
# 5 x 2= 10
# 5 x 3= 15
# 5 x 4= 20
# 5 x 5= 25
# 5 x 6= 30
# 5 x 7= 35
# 5 x 8= 40
# 5 x 9= 45
# 5 x 10= 50

# %%
# Countdown Timer
count = 5
while count > 0:
    print('Countdown:',count)
    count -= 1
print("Time's Up")
# Out:
# Countdown: 5
# Countdown: 4
# Countdown: 3
# Countdown: 2
# Countdown: 1
# Time's Up

# %%
# Collect user input
password = ''
while password != 'python123':
    password =input ('enter correct password')
print('Access granted')
# Out:
# enter correct password python123
# Access granted

# %%
# Find the lenght of thr list
my_list = [1,3,4,5,6,7,8]
print(len(my_list))
# Out:
# 7

# %%
# Get max value
nums = [10,20,80,30,40]
print(max(nums))
# Out:
# 80

# %%
# Area of rectangle

def rectangle_area(lenght,width):
    area = lenght * width

    return area

print(rectangle_area(10,5))
# Out:
# 50

# %%
print(rectangle_area(30,5))
# Out:
# 150

# %%
# Get max value
nums = [10,70,80,30,40]
print(max(nums))
# Out:
# 80

# %%
print(rectangle_area(10,3))
# Out:
# 30
